# %% [markdown]
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 5</b></center>
#     <center>Manav Delvadiya</center>
#     <center>24010101056</center>
#     <center>Roll No. - 333</center>
# <pre>

# %% [markdown]
# ### 1) Character Category Counter
# **Problem:** Count uppercase, lowercase, digits, and special characters in a string.
#
# **Sample Inputs & Outputs:**
# - Input: `Python3@Lab` → Uppercase: 2, Lowercase: 7, Digits: 1, Special: 1
# - Input: `HELLO123` → Uppercase: 5, Lowercase: 0, Digits: 3, Special: 0
# - Input: `hi@#9` → Uppercase: 0, Lowercase: 2, Digits: 1, Special: 2

# %%
s = input("Enter a String:");
s = list(s)
print(s)
upperCount=lowerCount=digitCount=specialCount = 0

for i in s:
    if(i.isupper()):
        upperCount += 1
    elif(i.islower()):
        lowerCount += 1
    elif(i.isdigit()):
        digitCount += 1
    else:
        specialCount += 1

print(f'Upper: {upperCount}, Lowercase: {lowerCount}, Digit: {digitCount}, Special: {specialCount}')
# Out:
# Enter a String: Python3@Lab
# ['P', 'y', 't', 'h', 'o', 'n', '3', '@', 'L', 'a', 'b']
# Upper: 2, Lowercase: 7, Digit: 1, Special: 1

# %% [markdown]
# ### 2) Reverse Each Word
# - Input: `Python is Easy` → `nohtyP si ysaE`
# - Input: `Hello World` → `olleH dlroW`
# - Input: `Learn Python Fast` → `nraeL nohtyP tsaF`

# %%
s = input("Enter a String:")
s = s.split()
print(s)

rev = ""
for i in s:
    rev += "".join(reversed(i))
    rev += " "

print(rev)
# Out:
# Enter a String: Python is Easy
# ['Python', 'is', 'Easy']
# nohtyP si ysaE

# %% [markdown]
# ### 3) Case Pattern Identifier
# - `PYTHON` → Uppercase
# - `python` → Lowercase
# - `Python Programming` → Title Case

# %%
s = input("Enter a String:")

if(s.isupper()):
    print("UpperCase")
elif(s.islower()):
    print("LowerCase")
elif(s.istitle()):
    print("TitleCase")
else:
    print("Another")
# Out:
# Enter a String: PYTHON
# UpperCase

# %% [markdown]
# ### 4) First and Last Occurrence Finder
# - `programming`, `g` → First:3 Last:10
# - `banana`, `a` → First:1 Last:5
# - `hello`, `z` → Not found

# %%
s = input("Enter a String:")
print(f'First:{s.find("g")} Last:{s.rfind("g")}')
# Out:
# Enter a String: programming
# First:3 Last:10

# %% [markdown]
# ### 5) Word Frequency Counter (ignore the case)
# - `Python is easy and Python is powerful` → python: 2
# - `Java is popular but java is verbose` → java: 2
# - `C is fast` → c:1

# %%
s = input("Enter a String:") 
ch = input("Enter a chareacter:")
s = s.lower()
ch = ch.lower()
print(f'count: {s.count(ch)}')
# Out:
# Enter a String: Python is easy and Python is powerful
# Enter a chareacter: PythoN
# count: 2

# %% [markdown]
# ### 6) Remove Extra Spaces
# - `  Python   is   fun  ` → `Python is fun`
# - `   Hello   World ` → `Hello World`
# - `NoExtraSpace` → `NoExtraSpace`

# %%
def remove_extra_spaces(text):
    return " ".join(text.split())
    
print(remove_extra_spaces("     Python   is   fun"))
print(remove_extra_spaces("  Hello   World  "))
print(remove_extra_spaces("NoExtraSpace"))
# Out:
# Python is fun
# Hello World
# NoExtraSpace

# %% [markdown]
# ### 7) Prefix and Suffix Removal
# - `unhappy.txt` → `happy`
# - `pretest.py` → `test`
# - `unwanted.doc` → `wanted`

# %%
s = "unhappy.txt"

s = s.replace("un", "", 1)

s = s.replace(".txt", "")

print(s)
# Out:
# happy

# %% [markdown]
# ### 8) Replace Vowels
# - `Programming` → `Pr*gr*mm*ng`
# - `Education` → `*d*c*t**n`
# - `Sky` → `Sky`

# %%
s = input("Enter a String :")
s = s.lower()
rep = ""
for i in s:
    if(i == "a" or i=="e" or i=="i" or i=="o" or i=="u"):
        rep += "*"
    else:
        rep += i
print(rep)
# Out:
# Enter a String : Programming
# pr*gr*mm*ng

# %% [markdown]
# ### 9) String Compression
# - `aaabbcccc` → `a3b2c4`
# - `xxxyyyz` → `x3y3z1`
# - `abcd` → `a1b1c1d1`

# %%
s = input("Enter a String: ")

i = 0
com = ""

while (i < len(s)):
    count = 1
    while (i + 1 < len(s) and s[i] == s[i + 1]):
        count += 1
        i += 1

    com = com + s[i] + str(count)
    i += 1

print(com)
# Out:
# Enter a String:  aaabbcccca
# a3b2c4a1

# %% [markdown]
# ### 10) Toggle Case (without using str.swapcase())
# - `PyThOn` → `pYtHoN`
# - `HELlo` → `helLO`
# - `Python` → `pYTHON`

# %%
s = input("Enter a Stirng:")
togg = ""

for i in s:
    if(i.islower()):
        togg += i.upper()
    elif(i.isupper()):
        togg += i.lower()

print(togg)
# Out:
# Enter a Stirng: HELlo
# helLO

# %% [markdown]
# ### 11) Username Validation
# #### valid username rules:
# 1. only alphabets and digits
# 2. does not start with a digit
# 3. length ≥ 6
#
# - `User123` → Valid
# - `123User` → Invalid
# - `Us@12` → Invalid

# %%
name = input("Enter a name:")

if(name.isalnum() and not(name[0].isdigit()) and len(name)>=6):
    print("Valid")
else:
    print("Invalid")
# Out:
# Enter a name: User123
# Valid

# %% [markdown]
# ### 12) Palindrome Checker (ignore the case)
# - `Madam` → Palindrome
# - `Level` → Palindrome
# - `Python` → Not Palindrome

# %%
s = input("Enter a Stirng:")
s = s.lower()
rev = s[::-1]

if(s == rev):
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Enter a Stirng: Level
# Palindrome

# %% [markdown]
# ### 13) Longest Word Finder
# - `Python programming is interesting` → programming
# - `I love coding` → coding
# - `Data structures and algorithms` → structures

# %%
s = input("Enter a Stirng:")
s = s.split()
print(s)
count = 0
word = ""

for i in s:
    if(len(i) > count):
        count = len(i)
        word = str(i)
print(word)
# Out:
# Enter a Stirng: Python programming is interesting
# ['Python', 'programming', 'is', 'interesting']
# programming

# %% [markdown]
# ### 14) Case Conversion
# - `python programming`
#   - Upper: PYTHON PROGRAMMING
#   - Lower: python programming
#   - Title: Python Programming
#   - Capitalize: Python programming

# %%
s = input("Enter a Stirng:")

print("Upper:", s.upper())
print("Lower:", s.lower())
print("Title:", s.title())
print("Capitalize:", s.capitalize())
# Out:
# Enter a Stirng: python programming
# Upper: PYTHON PROGRAMMING
# Lower: python programming
# Title: Python Programming
# Capitalize: Python programming

# %% [markdown]
# ### 15) Custom Split
# - `apple,banana,grape`
# - `10|20|30`
# - `A-B-C-D`

# %%
s = input("Enter a String:")
sep = input("Enter a Separator:")

print(s.split(sep))
# Out:
# Enter a String: apple,banana,grape
# Enter a Separator: ,
# ['apple', 'banana', 'grape']
