# %% [markdown]
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 11</b></center>
#     <center>Manav Delvadiya</center>
#     <center>24010101056</center>
#     <center>Roll No. - 333</center>
# <pre>

# %% [markdown]
# # Progrmas based on Python Data Structure + UDF + File Handling

# %% [markdown]
# ### Practical 1: Count Lines, Words and Characters
#
# **Problem Definition:**
# Write a Python program to read text from a file and count the total number of lines, words, and characters. The result should be written to an output file.

# %%
file = open("marks.txt")

lines = file.readlines()
line_count = len(lines)

word_count = 0
char_count = 0

for line in lines:
    word_count += len(line.split())
    char_count += len(line)

file.close()
print("File Read Successfully.")

out = open("output1.txt", "w")
out.write("Lines: " + str(line_count) + "\n")
out.write("Words: " + str(word_count) + "\n")
out.write("Characters: " + str(char_count))
out.close()
print("File Write Successfully.")
# Out:
# File Read Successfully.
# File Write Successfully.

# %% [markdown]
# ### Practical 2: Search a Word in a File
#
# **Problem Definition:**
# Write a Python program to search a given word in a text file and count its occurrences. Store the result in an output file.

# %%
word = input("Enter word to search: ")

file = open("file1.txt")
text = file.read()
file.close()
print("File Read Successfully.")
print("Text Data = ", text)

print(text.lower().split())

count = text.lower().split().count(word.lower())

out = open("output2.txt", "w")
out.write(f"Word {word} occurs {str(count)} times")
out.close()

print("File Write Successfully.")

 marks = list(data[2:])
    print("Marks = ",marks)

list(map(int, data[2:]))
 avg = average(marks)
    out.write(f"{roll} {name} Average = {avg}\n")
# Out:
# Enter word to search:  manav
# File Read Successfully.
# Text Data =  This is File1 Demo manav delvadiya
# manav patel delvadiya manav
#
# ['this', 'is', 'file1', 'demo', 'manav', 'delvadiya', 'manav', 'patel', 'delvadiya', 'manav']
# File Write Successfully.

# %% [markdown]
# ### Practical 3: Student Marks and Average
#
# **Problem Definition:**
# Write a Python program to read roll number, name, and marks of students from a file. Store marks in a list, calculate the average using a user-defined function, and write student details along with average marks to an output file.

# %%
def average(marks):
    print("marks = ",marks)
    data = list(int(i) for i in marks)
    print("data = ",data)
    return sum(data) / len(data)

file = open("StudentAvg.txt")
out = open("output3.txt", "a")

for line in file:
    data = line.split()
    roll = data[0]
    name = data[1]
    marks = list(data[2:])

    avg = average(marks)
    out.write(f" {str(roll)} {name} Average = {str(avg)}\n")

file.close()
out.close()
print("File Write Successfully.")
# Out:
# marks =  ['10', '20', '30', '40', '50']
# data =  [10, 20, 30, 40, 50]
# marks =  ['60', '70', '80', '90', '10']
# data =  [60, 70, 80, 90, 10]
# marks =  ['20', '30', '40', '50', '60']
# data =  [20, 30, 40, 50, 60]

# %% [markdown]
# ### Practical 4: Maximum and Minimum using Tuple
#
# **Problem Definition:**
# Write a Python program to read numbers from a file, store them in a tuple, and find the maximum and minimum values. Write the result to an output file.

# %%
file = open("marks.txt")
data = file.read().split()
numbers = tuple(int(i) for i in data)
print(number)

file.close()

maximum = max(numbers)
minimum = min(numbers)

out = open("output4.txt", "w")
out.write("Maximum = " + str(maximum) + "\n")
out.write("Minimum = " + str(minimum))
out.close()
# Out:
# (1, 2, 3, 4, 5, 6, 7)

# %% [markdown]
# ### Practical 5: Remove Duplicate Words using Set
#
# **Problem Definition:**
# Write a Python program to read words from a file and remove duplicate words using a set. Store the unique words in an output file.

# %%
file = open("file1.txt")
words = file.read().split()
file.close()

unique_words = set(words)

out = open("output5.txt", "w")
for word in unique_words:
    out.write(word + " ")
out.close()
print("File Write Successfully.")
# Out:
# File Write Successfully.

# %% [markdown]
# ### Practical 6: Word Frequency using Dictionary
#
# **Problem Definition:**
# Write a Python program to count the frequency of each word in a text file using a dictionary and write the result to an output file.

# %%
file = open("file1.txt")
words = file.read().split()
file.close()

freq = {}

for word in words:
    freq[word] = freq.get(word, 0) + 1

out = open("output6.txt", "w")
for word, count in freq.items():
    out.write(word + " : " + str(count) + "\n")
out.close()
print("File ")
# Out:
# File Write Successfully.

# %% [markdown]
# ### Practical 7: Student Result and Grade Calculation
#
# **Problem Definition:**
# Write a Python program to read roll number, name, and marks of students from a file. Use a user-defined function to determine grade (A/B/C/Fail) and write the student result to an output file.
#
# **Grade Criteria:**
# - Marks ≥ 75 : Grade A
# - Marks ≥ 60 : Grade B
# - Marks ≥ 40 : Grade C
# - Marks < 40 : Fail

# %%
def grade(marks):
    if marks >= 75:
        return "A"
    elif marks >= 60:
        return "B"
    elif marks >= 40:
        return "C"
    else:
        return "Fail"

file = open("Grade.txt", "r")
out = open("output7.txt", "w")

for line in file:
    roll, name, marks = line.split()
    print("Roll = ", roll)
    print("name = ", name)
    print("marks = ", marks)
    marks = int(marks)

    g = grade(marks)
    out.write(f"{roll} {name} Marks={marks} Grade={g}\n")

file.close()
out.close()
print("File Write Successfully.")
# Out:
# Roll =  101
# name =  Manav
# marks =  37
# Roll =  102
# name =  Patel
# marks =  79
# Roll =  103
# name =  Delvadiay
# marks =  99
# File Write Successfully.
