# %% [markdown]
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 10</b></center>
#     <center>Manav Delvadiya</center>
#     <center>24010101056</center>
#     <center>Roll No. - 333</center>
# <pre>

# %% [markdown]
# ### 01) WAP to read and display the contents of a text file. (also try to open the file in some other directory)
# #### - in the form of a string
# #### - line by line
# #### - in the form of a list

# %%
f = open("test.txt", "r")
data = f.read()
print(data)
f.close()

f = open("test.txt", "r")
for l in f:
    print(l,end="")
f.close()


f = open("test.txt", "r")
lines = f.readlines()
print(lines)
f.close()
# Out:
# ['Hello World 12345\n', '\n', 'line 2\n', 'line 3']

# %% [markdown]
# ### 02) WAP to create file named "new.txt" only if it doesn't exist.

# %%
import os
# Out:
# <_io.TextIOWrapper name='new.txt' mode='w' encoding='cp1252'>

# %% [markdown]
# ### 03) WAP to read first 5 lines from the text file.

# %%
f = open("test.txt", "r")
for i in range(5):
    print(f.readline(), end="")
f.close()
# Out:
# Hello World 12345
#
# line 2
# line 3

# %% [markdown]
# ### 04) WAP to find the longest word(s) in a file.

# %%
f = open("test.txt", "r")

words = f.read().split()
print("Words ==",words)

max_len = max(len(word) for word in words)
print("max_len ==",max_len)

longest_words = [word for word in words if len(word) == max_len]
print("Longest word(s):", longest_words)

f.close()
# Out:
# Words == ['Hello', 'World', '12345', 'line', '2', 'line', '3']
# max_len == 5
# Longest word(s): ['Hello', 'World', '12345']

# %% [markdown]
# ### 05) WAP to count the no. of lines, words and characters in a given text file.

# %%
f = open("test.txt", "r")
lines = f.readlines()

line_count = len(lines)
word_count = sum(len(line.split()) for line in lines)
char_count = sum(len(line) for line in lines)

print("Lines:", line_count)
print("Words:", word_count)
print("Characters:", char_count)
f.close()
# Out:
# Lines: 4
# Words: 7
# Characters: 32

# %% [markdown]
# ### 06) WAP to copy the content of a file to the another file.

# %%
f1 = open("test.txt", "r")
f2 = open("copy.txt", "w")

f2.write(f1.read())
print("Copy file successfully.")

f1.close()
f2.close()
# Out:
# Copy file successfully.

# %% [markdown]
# ### 07) WAP to find the size of the text file.

# %%
f = open("test.txt","r")
f.read()
size = f.tell()
print("SIZE =",size)
# Out:
# SIZE = 32

# %% [markdown]
# ### 08) WAP to create an UDF named frequency to count occurances of the specific word in a given text file.

# %%
def word_count(filename, word):
    f = open(filename, "r")
    data = f.read().split()
    print("Data = ",data)
    f.close()
    return data.count(word)

print(word_count("test.txt", "World"))
# Out:
# Data =  ['Hello', 'World', '12345', 'line', '2', 'line', '3']
# 1

# %% [markdown]
# ### 09) WAP to get the score of five subjects from the user, store them in a file. Fetch those marks and find the highest score.

# %%
f = open("marks.txt", "w")

for i in range(5):
    marks = int(input("Enter marks: "))
    f.write(str(marks) + "\n")

f.close()

f = open("marks.txt", "r")
data = (f.read().split("\n"))
print("data = ",data)
print("Highest Marks:", max(data))
f.close()
# Out:
# Enter marks:  1
# Enter marks:  2
# Enter marks:  3
# Enter marks:  4
# Enter marks:  5
# data =  ['1', '2', '3', '4', '5', '']
# Highest Marks: 5

# %% [markdown]
# ### 10) WAP to write first 100 prime numbers to a file named primenumbers.txt
# (Note: each number should be in new line)

# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, n):
        if n % i == 0:
            return False
    return True

f = open("primenumbers.txt", "w")
count = 0
num = 2

while count < 100:
    if is_prime(num):
        f.write(str(num) + "\n")
        count += 1
    num += 1

print("file write successfully.")
f.close()
# Out:
# file write successfully.

# %% [markdown]
# ### 11) WAP to merge two files and write it in a new file.

# %%
f1 = open("file1.txt", "r")
f2 = open("file2.txt", "r")
f3 = open("merged.txt", "a")

f3.write(f1.read())
f3.write(f2.read())

print("file merged successfully.")
f1.close()
f2.close()
f3.close()
# Out:
# file merged successfully.

# %% [markdown]
# ### 12) WAP to replace word1 by word2 of a text file. Write the updated data to new file.

# %%
f = open("test.txt", "r")
data = f.read()
f.close()

data = data.replace("world", "world2")

f = open("updated.txt", "w")
f.write(data)

print("File uodated successfully.")
f.close()
# Out:
# File uodated successfully.

# %% [markdown]
# ### 13) Demonstrate tell() and seek() for all the cases(seek from beginning-end-current position) taking a suitable example of your choice.

# %%
f = open("test.txt", "r")

print("Initial position:", f.tell())

f.read(10)
print("After reading 10 chars:", f.tell())

f.seek(0)
print("After seek from beginning:", f.tell())

f.close()
# Out:
# Initial position: 0
# After reading 10 chars: 10
# After seek from beginning: 0
