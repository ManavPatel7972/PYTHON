# %% [markdown]
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 2</b></center>
#     <center>Manav Delvadiya</center>
#     <center>24010101056</center>
#     <center>Roll No. - 333</center>
# <pre>

# %% [markdown]
# ### 01) WAP to print “Hello World..!!”

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### 02) WAP to accept your name and display a welcome message.
# #### Input: Priya
# #### Output: Hello Priya, welcome to Python Lab.

# %%
name = input("Enter a Name :")
print(f"Hello {name}, welcome to Python Lab")
# Out:
# Hello Manav, welcome to Python Lab

# %% [markdown]
# ### 03) WAP to accept three integers and display the numbers, their sum, and average.
# #### Input: 10 20 30
# #### Output:
# ##### Numbers: 10 20 30
# ##### Sum: 60
# ##### Average: 20.0

# %%
# a,b,c = int(intput("Enter a Three Number"));
# Error
# a = int(input("Enter a n1 :"));
# b = int(input("Enter a n2 :"));
# c = int(input("Enter a n3 :"));

# print(f"Numbers: {a} {b} {c}")
# print(f"Sum:{a+b+c}")
# print(f"Average:{(a+b+c)/3}");

a,b,c = map(int,input("Enter a Three Number :").split())
print(f"Numbers: {a} {b} {c}")
print(sum([a,b,c]))
print(sum([a,b,c])/3)
# Out:
# Numbers: 10 20 30
# 60
# 20.0

# %% [markdown]
# ### 04) WAP to accept name (string), age (int), and percentage (float).
# #### Input : Riya,18,92.5
# #### Output :
# ##### Name: Riya  Type: <class 'str'>
# ##### Age: 18  Type: <class 'int'>
# ##### Percentage: 92.5  Type: <class 'float'>

# %%
name = str(input("Enter a Name :"));
age = int(input("Enetr a Age :"));
percentage = float(input("ENetr a Percentage :"));

print(f"Name : {name}",f"Type: {type(name)}")
print(f"Age : {age}",f"Type: {type(age)}")
print(f"Percentage : {percentage}",f"Type: {type(percentage)}")
# Out:
# Name : Manav Type: <class 'str'>
# Age : 20 Type: <class 'int'>
# Percentage : 89.0 Type: <class 'float'>

# %% [markdown]
# ### 05) WAP to print folowing message using custom separator and end.
# #### Ouutput : Python | Programming | Basics###

# %%
print("Python","Programming","Basic",sep=" | ",end="###")
# Out:
# Python | Programming | Basic###

# %% [markdown]
# ### 06) WAP to accept a value and display its value, type, and memory id.
# #### Input : hello
# #### Output :
# ##### Value: hello
# ##### Type: <class 'str'>
# ##### ID: 140712345678912

# %%
var = input("Enter a Word : ")
print(f"Value:{var}")
print(f"Type:{type(var)}")
print(f"ID:{id(var)}")
# Out:
# Value:%%
# Type:<class 'str'>
# ID:1781907990944

# %% [markdown]
# ### 07) WAP to assign a value to a variable, print id, reassign a new value, and print id again.
# #### Output :
# ##### Original ID of a: 140712345678912
# ##### New ID of a: 140712345678960

# %%
var = 10;
print(f"Value:{var}");
print(f"Type:{type(var)}");
print(f"Original ID of a:{id(var)}");
var = 20;
print(f"New ID of a:{id(var)}");
var = 10;
print(f"Helllllll ID of a:{id(var)}")
# Out:
# Value:10
# Type:<class 'int'>
# Original ID of a:140705074230472
# New ID of a:140705074230792
# Helllllll ID of a:140705074230472

# %% [markdown]
# ### 08) WAP to print multiple lines using a single print().
# #### Output:
# ##### Welcome to Python
# ##### This is the second lab
# ##### Enjoy coding!

# %%
print("""
Welcome to Python
This is the second lab
Enjoy coding!  
""")
# Out:
# Welcome to Python
# This is the second lab
# Enjoy coding!

# %% [markdown]
# ### 09) WAP to display following table of items with proper alignment.
# #### Output :
# | Sr No | Name        | Subject | Grade | Percentage |
# | ----: | ----------- | ------- | :---: | ---------: |
# |     1 | Nisha Patel | Math    |   A   |         92 |
# |     2 | Aarav Modi  | Science |   B+  |         85 |
# |     3 | Jiya Shah   | English |   A+  |         96 |

# %%
print(f" {'Sr No':^10}  {'name':>10}  {'subject':>10}  {'Grade':>10}  {'percentage':>10}")
print(f" {'1':>10}  {'Nisha Patel':>10}  {'Math':>10}  {'A':>9}  {'92':>10}")
print(f" {'2':>10}  {'Aarav Modi':>11}  {'Science':>10}  {'B+':>10}  {'85':>9}")
print(f" {'3':>10}  {'Jiya Shah':>10}  {'English':>11}  {'A+':>10}  {'96':>9}")


# print("Welcome to Python\nThis is the second lab\nEnjoy coding!")
# print("Sr No.\tName\t\tAge\tPercentage")
# print("1\tJohn Doe\t20\t85.5")
# print("2\tJane Smith\t22\t90.0")
# print("3\tAlice Johnson\t19\t92.3")
# Out:
#    Sr No           name     subject       Grade  percentage
#           1  Nisha Patel        Math          A          92
#           2   Aarav Modi     Science          B+         85
#           3   Jiya Shah      English          A+         96

# %% [markdown]
# ### 10) WAP to accept a float number and display with 2 decimals, 3 decimals, and width 10.
# #### Input : 37.2567
# #### Output :
# ##### 2 decimals: 37.26
# ##### 3 decimals: 37.257
# ##### Width 10:      37.26

# %%
num = float(input("Enter a Number :"));
print(f"2 decimals:{num:.2f}");
print(f"3 decimals:{num:.3f}");
print(f"Width 10:{num:10.2f}");
# Out:
# 2 decimals:235647.00
# 3 decimals:235647.000
# Width 10: 235647.00

# %% [markdown]
# ### 11) WAP to accept two integers and display sum, difference, and product using f-strings.
# #### Input : 12 8
# #### Output :
# ##### Sum = 20
# ##### Difference = 4
# ##### Product = 96

# %%
n1 = int(input("Enter a n1 :"));
n2 = int(input("Enter a n2 :"));
print(f"Sum = {n1+n2}");
print(f"Diffreance = {n1-n2}");
print(f"Product = {n1*n2}");
# Out:
# Enter a n1 : 12
# Enter a n2 : 8
# Sum = 20
# Diffreance = 4
# Product = 96

# %% [markdown]
# ### 12) WAP to accept date in dd mm yyyy format and display in multiple formats.
# #### Input : 01 12 2025
# #### Output :
# ##### 01/12/2025
# ##### 2025-12-01

# %%
date = input("Enter a Date (dd mm yyyy) :");
[dd,mm,yyyy] = date.split(" ");

print(dd,mm,yyyy,sep="/");
print(yyyy,mm,dd,sep="-");
# Out:
# 22/04/2022
# 2022-04-22

# %% [markdown]
# ### 13) WAP to calculate area and perimeter of a circle.

# %%
# import math

# r = float(input("Enter a radius :"))
# perimeter = 2 * math.pi * r;
# area = math.pi * r * r;
# print(f"perimeter = {perimeter}")
# print(f"Area = {area}");

from math import pi
r = float(input("Enter a radius :"))

area = pi * r * r
perimeter = 2 * pi * r
print(f"perimeter = {perimeter}")
print(f"Area = {area}");
# Out:
# perimeter = 62.83185307179586
# Area = 314.1592653589793

# %% [markdown]
# ### 14) WAP to convert degree into Fahrenheit and vice versa.

# %%
deg = float(input("Enter a Degree :"));
fah = float(input("Enter a Fahrenhit : "));

degToFah = (deg * 1.8) + 32;
fahToDeg = (fah - 32)/1.8;

print(f"degToFah : {degToFah}");
print(f"fahToDeg : {fahToDeg}");
# Out:
# Enter a Degree : 5
# Enter a Fahrenhit :  41
# degToFah : 41.0
# fahToDeg : 5.0

# %% [markdown]
# ### 15) WAP to get the distance from user into kilometer, and convert it into meter, feet, inches and centimeter.

# %%
distKm = int(input("Enter a Distance in Kilometer : "));

meter = (distKm) * 1000;
feet = (distKm) *3280.84;
inch = (distKm) * 39370.1;
centimeter = (distKm) * 100000;

print(f"{distKm} KM = {meter} Meter")
print(f"{distKm} KM = {feet} Feet")
print(f"{distKm} KM = {inch} Inches")
print(f"{distKm} KM = {centimeter} Centimeter");
# Out:
# Enter a Distance in Kilometer :  5
# 5 KM = 5000 Meter
# 5 KM = 16404.2 Feet
# 5 KM = 196850.5 Inches
# 5 KM = 500000 Centimeter
